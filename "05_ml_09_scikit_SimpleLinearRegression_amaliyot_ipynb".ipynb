# %% [markdown]
# <a href="https://colab.research.google.com/github/jurabekkholiqov/Kholikov_01s/blob/main/%2205_ml_09_scikit_SimpleLinearRegression_amaliyot_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 5-MODUL. Machine Learning.
#
# ### Amaliyot. Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/reklama_sales.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# Yuqoridagi jadvalda MohirDev MChJ tomonidan turli OAV larda (`TV`, `Radio`, `Newspaper`) berilgan reklamalar soni va mos keluvchi savdolar (`Sales`) berilgan.
#
# Sizning vazifangiz:
# 1. Aynan qaysi turdagi OAVda reklama berish savdo o'sishiga ta'sir qiladi aniqlash
# 2. Topilgan bog'liqlik asosida Simple Linear Regression algorithmi yordamida bashorat modelini qurish.

# %% [markdown]
# Ushbu amaliyotda sizning vazifangiz berilgan dataset yordamida Simple Linear Regression model yaratish:
# - CRISP-DM metodologiyasiga amal qiling!
# - Simple linear regression qo'llash uchun 1 ta ustunni tanlab oling.

# %%
fig, ax = plt.subplots(1,3, figsize=(10,4))
sns.regplot(data=df, x='TV', y='Sales', ax=ax[0],   line_kws={'color':'red'})
sns.regplot(data=df, x='Radio', y='Sales', ax=ax[1],  line_kws={'color':'g'})
sns.regplot(data=df, x='Newspaper', y='Sales', ax=ax[2],   line_kws={'color':'y'})
plt.show()

# %% [markdown]
# ##Xulosa
# #Demak TV da reklama bizning sotuvimiz uchun ko'proq foyda olib kelar ekan.

# %%
df.shape
# Out:
# (200, 4)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.1, random_state=42)

# %%
from sklearn import linear_model
LR_model = linear_model.LinearRegression()

# %%
x_train = np.asanyarray(train_set[['TV']])
y_train = np.asanyarray(train_set[['Sales']])

# %%
LR_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
theta1 = LR_model.coef_[0][0]
theta0 = LR_model.intercept_[0]
print(f"{theta1=}")
print(f"{theta0=}")
# Out:
# theta1=np.float64(0.05513263076693964)
# theta0=np.float64(7.044916461655207)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TV', y='Sales')
plt.plot(x_train, theta1*x_train + theta0, '-r')
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()

# %%
x_test = np.asanyarray(test_set[['TV']])
y_test = np.asanyarray(test_set[['Sales']])

# %%
y_predict = LR_model.predict(x_test)
y_predict
# Out:
# array([[16.04807507],
#        [17.81783251],
#        [23.19326401],
#        [ 7.68996824],
#        [19.19063502],
#        [11.18537703],
#        [18.99767081],
#        [ 9.801548  ],
#        [19.30641354],
#        [16.69864011],
#        [ 8.78159433],
#        [10.14337031],
#        [19.97351838],
#        [ 7.34263267],
#        [14.73591845],
#        [16.42849022],
#        [ 7.44738467],
#        [17.9391243 ],
#        [11.19640356],
#        [20.13340301]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
MAE = mean_absolute_error(y_test, y_predict)
RMSE = np.sqrt(mean_squared_error(y_test, y_predict))
print(f"{MAE=}")
print(f"{RMSE=}")
# Out:
# MAE=2.037955356968121
# RMSE=np.float64(2.5103822386472214)

# %%
y_predict
# Out:
# array([[16.04807507],
#        [17.81783251],
#        [23.19326401],
#        [ 7.68996824],
#        [19.19063502],
#        [11.18537703],
#        [18.99767081],
#        [ 9.801548  ],
#        [19.30641354],
#        [16.69864011],
#        [ 8.78159433],
#        [10.14337031],
#        [19.97351838],
#        [ 7.34263267],
#        [14.73591845],
#        [16.42849022],
#        [ 7.44738467],
#        [17.9391243 ],
#        [11.19640356],
#        [20.13340301]])

# %%
y_test
# Out:
# array([[16.9],
#        [22.4],
#        [21.4],
#        [ 7.3],
#        [24.7],
#        [12.6],
#        [22.3],
#        [ 8.4],
#        [16.5],
#        [16.1],
#        [11. ],
#        [ 8.7],
#        [16.9],
#        [ 5.3],
#        [10.3],
#        [16.7],
#        [ 5.5],
#        [16.6],
#        [11.3],
#        [18.9]])
